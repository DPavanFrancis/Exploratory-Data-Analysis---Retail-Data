# %% [markdown]
# # The Sparks Foundation
# # Data Science & Business Analytics

# %% [markdown]
# # Exploratory Data Analysis - Retail
# # Author:- D Pavan Kumar

# %% [markdown]
# # TASK-3

# %% [markdown]
# Exploratory data analysis is the Process of analyzing the datasets to summarize their main features using numerical and
#   and visual methods
#
# The Task is to do data analysis on given retail data,using the Exploratory Data Analysis techniques.
#
# Here, we are dealing with the Retail data set

# %%
#Let's start with importing required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading CSV data
df=pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# Data variables  represents
#
# (1)ship mode -- this variable explains type of ship mode class for a retail items
#
# (2)Segment -- segment explains the retail shipped to which type of segment.And their are 3 types of segment
#
# (3)Country -- Retail shipped to which country
# (4)City   --  Retail shipped to which city
# (5)state  -- Retail shipped to which state
#
# (6)code -- retail item shipped city code
#
# (7)Region-- retail item shipped to which rgion in the country
#
# (8)Category-- retail item category type.Their are 3 types in it.
# (9)Sub-category--retail item sub-category types.
# (10)Sales -- Sales in Dollars
#
# (11)Quantiuty -- Quantity of retail item shipped
# (12)Discount -- Discount on retail items shipped
# (13)Profit -- Profit gained

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# Above noticied that 'Postal Code','Sales','Quantity','Discount','Profit' are numerical features rest all are Categorical.

# %%
df=df.drop('Postal Code',axis=1)  #removed the insignificant variable

# %%
df.columns   # Hence, 'Postal Code' variable eliminated from the data.
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# 'Postal code' variable is eliminated because it is an insignificant variable

# %%
df.duplicated().sum()  #their are 50 duplicated values present in the Data.
# Out:
# 50

# %%
df=df.drop_duplicates() # droping the duplicates permanently.
df.shape
# Out:
# (9944, 12)

# %%
df.isnull().sum()  # Their are No missing values in it
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
sns.heatmap(df.isnull(),annot=True)   # Visualization tells that their are no null values
plt.show()

# %% [markdown]
# Now,their are no duplicate values and no missing values in the data.

# %% [markdown]
# # Summary of Data:

# %%
df.describe()  #  default gives the summary of Numeric variables
# Out:
#               Sales     Quantity     Discount       Profit
# count   9944.000000  9944.000000  9944.000000  9944.000000
# mean     230.752150     3.794047     0.156440    28.770873
# std      624.644765     2.228752     0.206584   234.841370
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.340000     2.000000     0.000000     1.724800
# 50%       55.000000     3.000000     0.200000     8.679950
# 75%      210.104000     5.000000     0.200000    29.534700
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# The DataFrame shows the summary of the numeric variables from the dataset.

# %% [markdown]
# df.describe()-- gives summary of Numeric data
#
# Summary:
#
#     1.The Average Sales for superstore is 230.75
#     2.And Standard deviation 624.64
#     3.Maximum discount given 80%
#     4.Maximum profit is $8399
#     5.Record high Quantity retailed in shippment is 14 items.

# %%
df.describe(include='O')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9944      9944           9944           9944        9944
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5930      5160           9944            906        1980
#
#        Region         Category Sub-Category
# count    9944             9944         9944
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3177             5986         1518

# %% [markdown]
# df.describe(include='O')--gives the summary of categorical data.
#
# summary:
#
#     1.Their are 4 types of shipment modes
#     2.Their are 3 types of Sub-categories in the Segment Variable.
#     3.Their are 531 cities & 49 states & 4 regions and only one Contry.
#     4.Their are 3 types of Category Items in the store
#     5.Their are 17 types of Sub-Categories in store.

# %% [markdown]
# NOTICE:
#
#     #In the above data,data explains about Retail Superstore all over the USA Country only.
#     #So,Their is no much importance of 'Country' column.
#     #So,Eliminating the 'country' column.

# %%
df=df.drop('Country',axis=1)

# %%
df.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# # Analyzing Each Categorical variable:

# %%
print(df['Ship Mode'].value_counts())
df['Ship Mode'].value_counts().plot(kind='barh')  # Maximum shipmode approached by standard class only
# Out:
# Standard Class    5930
# Second Class      1941
# First Class       1531
# Same Day           542
# Name: Ship Mode, dtype: int64
# <AxesSubplot:>

# %%
sns.barplot(data=df,x=df['Ship Mode'],y=df.Sales,hue=df['Region'])
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %% [markdown]
# Second class shipmode is doing well in all types of classes in the Country

# %%
print(df.Segment.value_counts())
df.Segment.value_counts().plot(kind='bar',color='red')
# Out:
# Consumer       5160
# Corporate      3008
# Home Office    1776
# Name: Segment, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# By the Graph,conclude that consumer retail is more than Home,Corporate.And we have to improve the Home/Office segments

# %%
sns.barplot(data=df,x=df.Segment,y=df.Sales,hue=df.Region)
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %% [markdown]
# In the Central region,sales are low comparing to other.So,we need to take up the lead and improve

# %%
print(df.City.value_counts())
len(df.City.value_counts())
# Out:
# New York City      906
# Los Angeles        734
# Philadelphia       531
# San Francisco      503
# Seattle            424
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64
# 531

# %% [markdown]
# The retail superstore located in the 531 cities.

# %%
print(df.State.value_counts())
len(df.State.value_counts())
# Out:
# California              1980
# New York                1119
# Texas                    980
# Pennsylvania             581
# Washington               502
# Illinois                 490
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %% [markdown]
# 49 states of USA Country contains Superstore Branches

# %%
plt.figure(figsize=(14,12))
sns.countplot(data=df,x=df.State)
plt.xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %% [markdown]
# The retail superstore located in the 49 states.

# %%
df.Region.value_counts()
# Out:
# West       3177
# East       2832
# Central    2315
# South      1620
# Name: Region, dtype: int64

# %% [markdown]
# The retail superstore branches are more in the west region.And minimum in the south region.

# %%
sns.countplot(data=df,x=df.Region)  # visualization for above data
plt.text(x = 0.01, y = df.Region.value_counts()[3], s = df.Region.value_counts()[3])
plt.text(x = 0.90, y = df.Region.value_counts()[0], s = df.Region.value_counts()[0])
plt.text(x = 1.70, y = df.Region.value_counts()[2], s = df.Region.value_counts()[2])
plt.text(x = 2.80, y = df.Region.value_counts()[1], s = df.Region.value_counts()[1])
plt.show()

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# Central    500724.2708
# East       677843.9080
# South      391721.9050
# West       724309.2935
# Name: Sales, dtype: float64

# %% [markdown]
# South region has minimum in Sales And West region has maximum in Sales

# %%
df.Category.value_counts()
# Out:
# Office Supplies    5986
# Furniture          2114
# Technology         1844
# Name: Category, dtype: int64

# %%
df.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          740568.6663
# Office Supplies    718256.0700
# Technology         835774.6410
# Name: Sales, dtype: float64

# %%
df.groupby('Category')['Sales'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# As Visualization tells that,Most of the Technology Category items were Maximum in sales wise.

# %%
df.groupby('Category')['Sub-Category'].value_counts()
# Out:
# Category         Sub-Category
# Furniture        Furnishings      954
#                  Chairs           615
#                  Tables           319
#                  Bookcases        226
# Office Supplies  Binders         1518
#                  Paper           1344
#                  Storage          845
#                  Art              793
#                  Appliances       466
#                  Labels           359
#                  Envelopes        254
#                  Fasteners        217
#                  Supplies         190
# Technology       Phones           888
#                  Accessories      773
#                  Machines         115
#                  Copiers           68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# The above Category&Sub-category Items are available in the Superstore

# %%
print(df['Sub-Category'].value_counts())
len(df['Sub-Category'].value_counts())         # their are 17 different types of sub-category items in Superstore
# Out:
# Binders        1518
# Paper          1344
# Furnishings     954
# Phones          888
# Storage         845
# Art             793
# Accessories     773
# Chairs          615
# Appliances      466
# Labels          359
# Tables          319
# Envelopes       254
# Bookcases       226
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64
# 17

# %%
plt.figure(figsize=(10,10))
df['Sub-Category'].value_counts().plot(kind='barh',color='orange')
plt.show()

# %% [markdown]
# As from the above Visualization,the most sold Sub-category items are Binders & Paper.

# %% [markdown]
# # Distribution of the Data

# %%
plt.rcParams['figure.figsize']=[16,8]

# %%
df.hist()
plt.show()

# %%
df.skew()
# Out:
# Sales       12.946427
# Quantity     1.273812
# Discount     1.681206
# Profit       7.541727
# dtype: float64

# %% [markdown]
# The variables are positively skewed

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200469 -0.028625  0.479078
# Quantity  0.200469  1.000000  0.008307  0.066089
# Discount -0.028625  0.008307  1.000000 -0.219939
# Profit    0.479078  0.066089 -0.219939  1.000000

# %%
sns.heatmap(df.corr(),annot=True,cbar=True,cmap="YlGnBu")
plt.show()

# %% [markdown]
# It can be observe that the numeric variables are not correlated with each other since all the correlation coefficients are close to zero, however profit and sales show some correlation

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'City', 'State', 'Region', 'Category',
#        'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df_cat=df.select_dtypes(include='O')
df_num=df.select_dtypes(include=np.number)

# %%
# Plot the count distribution for each categorical variable 
# 'figsize' sets the figure size
fig, ax = plt.subplots(4, 2, figsize=(28, 22))

# plot a count plot for all the categorical variables
for variable, subplot in zip(df_cat, ax.flatten()):
    
    # plot the count plot using countplot()
    # y:y axis represents the variable from df_cat
    # ax: specifies the axes object to draw the plot onto
    countplot = sns.countplot(y=df[variable], ax=subplot )
       
    # Set the y-axis labels 
    # Fontsize = 30: sets the font size to 30
    countplot.set_ylabel(variable, fontsize = 30)

# Avoid overlapping of the plots using tight_layout()    
plt.tight_layout()   
# Display the plot
plt.show()

# %% [markdown]
# Maximum shipment was through Standard class,when we look at the regionally west region takes the highest sales.
#
# When we see the Sub-category,Binders sold most followed by Papers & Furnishings,which are mostly belong to office supplies
#
# The Consumer segment caused the Maximum sales

# %% [markdown]
# # Pairwise relation between all the numeric variables

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# At the lower sales the profit is not certain ,but it gives profit at when the sales is high.

# %%
df.groupby(['Region'])[['Sales','Profit']].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Region'>

# %% [markdown]
# The Highest Sales & Profit gained in west region,followed by East region.
#
# South region takes lowest in sales,followed by central region which is having the least profit compare to other regions.

# %%
df_state_quantity=df.groupby(['State'])['Quantity'].sum().sort_values(ascending=False)
df_state_quantity
# Out:
# State
# California              7602
# New York                4202
# Texas                   3710
# Pennsylvania            2133
# Washington              1871
# Illinois                1840
# Ohio                    1757
# Florida                 1379
# North Carolina           983
# Michigan                 943
# Virginia                 893
# Arizona                  862
# Georgia                  705
# Colorado                 693
# Tennessee                681
# Indiana                  578
# Kentucky                 523
# Oregon                   497
# Massachusetts            491
# Wisconsin                463
# New Jersey               454
# Maryland                 420
# Delaware                 367
# Minnesota                331
# Connecticut              281
# Alabama                  256
# Missouri                 252
# Oklahoma                 247
# Arkansas                 240
# Mississippi              221
# Utah                     219
# Rhode Island             199
# ...

# %%
df_state_quantity=df.groupby(['State'])['Quantity'].sum().sort_values(ascending=False).plot(kind='bar',color='Green')
plt.title('Quantity sold to states')
plt.xlabel('States')
plt.ylabel('Quantity')
plt.show()

# %% [markdown]
# The highest amount of quantity sold to California, with almost 7000+ Quantity shipped.
#
# New York has the second highest Quantity Sold, with around 4000+ Quantity shipped.
#
# Texas is third with almost 3600 of total Quantity shipped.
#
# we need to improve more where the quantity shippment happened <200 because it leads the loss for Superstore Market around the country."Wyoming state" superstore branch shows almost Zero.

# %%
sns.scatterplot(df['Profit'],df['Sales'],hue=df['Discount'])  
plt.show()

# %% [markdown]
# In the market,when we give Discounts 15% to 30% range then the Max.Profit earning is 8000 USD
# And In the market,when we give Discounts huge amount then the Superstore facing no Profit and also facing huge loss mostly
# around 6000+ USD Loss for the Superstores

# %%
df_state_sales=df.groupby(['State'])['Sales'].sum().sort_values(ascending=False).plot(kind='bar',color='Yellow')
plt.title('State wide sales')
plt.xlabel('States')
plt.ylabel('Sum of Sales')
plt.show()

# %% [markdown]
# As for the previous analysis,the top 3 states having maximun no.of Quantity & Maximum Sum of Sales is Same.
#
# Superstore highest sales in the state of California, with over USD 450K of total sum of sales.
#
# New York has the second highest sales,with over USD 300k of total sum of sales.
#
# Texas is third highest with around USD 170K of total sum of sales.
#
# The states of Wyoming, South Dakota, Maine, West Virginia, and North Dakota have comparatively negligible sales.
#  marketing strategies should be improved in these areas as well as the states with less than USD 50k total sales.

# %%
df_state_profit=df.groupby(['State'])['Profit'].sum().sort_values(ascending=False).plot(kind='bar',color='Violet') #State wide Profit/loss
plt.title('State wide Profit/loss')
plt.xlabel('States')
plt.ylabel('Profit/loss')
plt.show()

# %%
df_state_sales=df.groupby(['State'])['Discount'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title('State wide discount')
plt.xlabel('States')
plt.ylabel('Discounts')
plt.show()

# %% [markdown]
# It is clearly observed from visualization that Huge loses took place because of High discounts
# in the Superstore in those States.
#
# And More Profit Gained only because of Minimal discounts in the states where Superstore doing well in Market statistics

# %%
df_subcategory_deals=df.groupby(['Sub-Category'])['Quantity'].sum().sort_values(ascending=False).plot(kind='bar',color='Black')
plt.title('Toatal Quantity sold in sub-categories')
plt.xlabel('Sub-Categories')
plt.ylabel('Quantity')
plt.show()

# %% [markdown]
# Binders were sold in the largest quantity with almost 6000 units of Sub-category Quantity,followed by paper with 5000 units with a gap of 1500 units from the highest selling products the Furnishings,Phones,Storage,Art,Accessories,chairs are sold in the Superstores upto more than 2500 units to 3500 units.
#
# The need of products like Bookcases,Copires ,Machines are quite less.

# %%
Table=pd.crosstab(index=df['Region'],columns=df['Ship Mode'],values=df['Profit'],aggfunc='sum')
Table
# Out:
# Ship Mode  First Class   Same Day  Second Class  Standard Class
# Region
# Central      3691.0834  1531.8797     9121.0719      25318.0124
# East        15726.5709  7980.2670    10775.5420      56988.7110
# South        6892.3854 -1762.3350    14667.1469      26952.2330
# West        22600.4080  8122.0752    22861.8108      54630.6953

# %%
Table_Graph=pd.crosstab(index=df['Region'],columns=df['Ship Mode'],values=df['Profit'],aggfunc='sum').plot(kind='bar')
Table_Graph
plt.title('Bar Graph of Profit gained in the Regions along with Shippment Modes')
plt.show()

# %% [markdown]
# In all of the 4 regions,Standard class is the most preferred shipment mode giving the high profits .
# Second class ship mode acquires the second position after standard class,with a big trailing gap Shipments going out on the same day of order are showing the lowest profits,the arrangements for the transportation may be reason for loss.
#
# In south region shipments on the day of order are going through a loss

# %%
pd.crosstab(index=df['Segment'],columns=df['Category'],values=df['Sales'],aggfunc='sum')
# Out:
# Category       Furniture  Office Supplies  Technology
# Segment
# Consumer     389931.7150       363465.294  406020.505
# Corporate    229009.7658       230510.310  246450.119
# Home Office  121627.1855       124280.466  183304.017

# %%
pd.crosstab(index=df['Segment'],columns=df['Category'],values=df['Sales'],aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Segment'>

# %% [markdown]
# Consumers are interested in purchasing the products in technology category,the sales are approximately USD 400K in this
# segment then the furniture sales are closer to USD 400K and Office supplies are giving the sales more than USD 350K.
#
# In the corporate sector products from technology category giving the highest sales followed by Office Supplies,Furnitures.
# And they are not at any bigger gap from the sales among each other.
# where, Technology products sales almost USD 250K;
#        Office supllies sales are around USD 225K;
#        And Furniture sales are around USD 225K.
#
# Home office segment are taking the sales from USD 120K to USD 175K in the categories like Furnitures,Office supplies and
# Technology products respectively.

# %%
sns.stripplot(x=df.Region,y=df.Sales)
plt.show()

# %% [markdown]
# # State_wide_Total_sales For Superstores :

# %%
df.groupby('State')['Sales'].sum().sort_values()
# Out:
# State
# North Dakota               919.9100
# West Virginia             1209.8240
# Maine                     1270.5300
# South Dakota              1315.5600
# Wyoming                   1603.1360
# District of Columbia      2865.0200
# Kansas                    2914.3100
# Idaho                     4382.4860
# Iowa                      4579.7600
# New Mexico                4783.5220
# Montana                   5589.3520
# New Hampshire             7292.5240
# Nebraska                  7464.9300
# South Carolina            8481.7100
# Vermont                   8929.3700
# Louisiana                 9217.0300
# Mississippi              10771.3400
# Utah                     11220.0560
# Arkansas                 11678.1300
# Connecticut              13384.3570
# Nevada                   16729.1020
# Oregon                   17420.7820
# Alabama                  19510.6400
# Oklahoma                 19683.3900
# Missouri                 22205.1500
# Rhode Island             22627.9560
# ...

# %%
df.groupby('State')['Sales'].sum().sort_values().plot(kind='bar',color='skyblue')
# Out:
# <AxesSubplot:xlabel='State'>

# %% [markdown]
# By noticing from Graph,states like 'Pennsylvania','Washington','Texas','New york','California' are having
# more than 100K USD total sales from Superstore Branches.

# %% [markdown]
# By observig that states like 'North Dakota','West Viriginia','Maine','South Dakota','Wyoming' are having <2000 USD
# total sales

# %% [markdown]
# # Total No.of Superstores for Each State:

# %%
print(df.groupby('State')['City'].count().sort_values())
df.groupby('State')['City'].count().sort_values().plot(kind='bar',color='Pink')
# Out:
# State
# Wyoming                    1
# West Virginia              4
# North Dakota               7
# Maine                      8
# District of Columbia      10
# Vermont                   11
# South Dakota              12
# Montana                   15
# Idaho                     21
# Kansas                    24
# New Hampshire             27
# Iowa                      30
# New Mexico                37
# Nebraska                  38
# Nevada                    39
# South Carolina            42
# Louisiana                 42
# Utah                      53
# Mississippi               53
# Rhode Island              56
# Arkansas                  60
# Alabama                   61
# Oklahoma                  66
# Missouri                  66
# Connecticut               82
# Minnesota                 89
# Delaware                  96
# Maryland                 105
# Wisconsin                110
# Oregon                   123
# New Jersey               130
# Massachusetts            135
# ...

# %%
a=df.groupby('State')['City'].count().sort_values()
a[a<50].sort_values()
# Out:
# State
# Wyoming                  1
# West Virginia            4
# North Dakota             7
# Maine                    8
# District of Columbia    10
# Vermont                 11
# South Dakota            12
# Montana                 15
# Idaho                   21
# Kansas                  24
# New Hampshire           27
# Iowa                    30
# New Mexico              37
# Nebraska                38
# Nevada                  39
# South Carolina          42
# Louisiana               42
# Name: City, dtype: int64

# %% [markdown]
# Their are 27 states are having less than 100 superstore Branches.
# And among them,17 States are having less than 50 Superstore Branches.

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Their are 27 states are having less than 100 superstore Branches.And amoung them,17 States are having less than 50 Superstore Branches.And we need to improve,this states superstore branches by increasing the Superstore branches and increasing the Sub-category items in each store and dealing with discount sales will manage to improve sales and profit.
# This 27 states superstore branches are very weak.we should work on it for better results.

# %% [markdown]
# States like 'Oregon','Florida','Arizona','tennessee','Colorado','North carolina','Illinois','Pennsylvania','Ohio','Texas'
# are in the huge downfall of loss because of unbalanced discounts on sales

# %% [markdown]
# By observig that states like 'North Dakota','West Viriginia','Maine','South Dakota','Wyoming' are having <2000 USD
# total sales

# %% [markdown]
# By noticing from Graph,states like 'Pennsylvania','Washington','Texas','New york','California' are having
# more than 100K USD total sales from Superstore Branches.

# %% [markdown]
# By increasing the stores in the States and mainly balancing the discounts on Sales is very important
# to escape from the loss in the market.And we need to provide all the category items in the store is very important.
#
#
# Furniture sub-categories as well as Appliances and Binders under the Office Supplies category contribute to a majority
# of losses.Superstore is advised to improve on the promotional strategies for these, as well as reduce overall discounts.

# %% [markdown]
# the sub-categories of Copiers, Accessories, Phones, Envelopes, and Paper are quite definitely profitable.

# %% [markdown]
# # THANK YOU
